# %% [markdown]
# <a href="https://colab.research.google.com/github/S-Devisri01/Python-colab/blob/main/Python_gen_ai_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
   print("Hi Everyone")
greet()
x=10
y=20
print(x+y)
# Out:
# Hi Everyone
# 30

# %%
def add(a,b,c):
  return a + b + c
print(add(10,40,50))
print(add(30,40,25))
# Out:
# 100
# 95

# %%
def greet(name="Devisri"):
  print("Hi", name)
greet()
greet("Dear")
greet("Sri")
# Out:
# Hi Devisri
# Hi Dear
# Hi Sri

# %%
#local variable
def sub():
  a=10
  print(a)
sub()

#global variable
a=15
def de():
  print(a)
de()
# print(a)
# sub()
# Out:
# 10
# 15

# %%
#list
L1=[10,30,20,40]
print(L1[2])
L1.append(50)
print(L1)
L1.remove(30)
print(L1)
L1.sort()
print(L1)
L1.sort(reverse=True)
print(L1)
# Out:
# 20
# [10, 30, 20, 40, 50]
# [10, 20, 40, 50]
# [10, 20, 40, 50]
# [50, 40, 20, 10]

# %%
#dictionary
student={"name":"Devisri","age":21}
print(student)
print(student["name"])
print(student["age"])
student["age"]=22
print(student["age"])
student["grade"]="O"
print(student["grade"])
# Out:
# {'name': 'Devisri', 'age': 21}
# Devisri
# 21
# 22
# O

# %%
#tuple
colors=("red","black","yellow")
print(colors)
# Out:
# ('red', 'black', 'yellow')

# %%
#set
num={1,2,3,2,3,1,4,5,5,3}
print(num)
# Out:
# {1, 2, 3, 4, 5}

# %%
#string
# text="Python Learning"
# print(text.upper())
# print(text.lower())
# print(text.replace("Learning","Practicing"))
# print(text.split())
text=input('Enter a text:')
print(text.upper())
print(text.lower())
# Out:
# Enter a text:Dear
# DEAR
# dear

# %%
# function that returns the square of num
def square(num):
    return num * num
print(square(5))
# Out:
# 25

# %%
# functiom to check even or odd
def check(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"
print(check(7))
print(check(8))
# Out:
# Odd
# Even

# %%
# find a largest num in list
numbers = [10, 45, 23, 89, 12]
largest = max(numbers)
print("Largest:", largest)
# Out:
# Largest: 89
